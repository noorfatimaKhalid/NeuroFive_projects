# %%
import numpy as np
import pandas as pd
from word2number import w2n
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier

# %%
df=pd.read_csv("Patient_Health_Records_Raw.csv")

# %%
df.sample(5)
# Out:
#      Patient_ID            Name    Age  Gender      City      BMI  \
# 9355   ID-09356       Jane  Doe    NaN  FEMALE  Nwe Yrok  22kg/m2
# 7670   ID-07671   michael brown   -5.0       M   Chicago      NaN
# 35     ID-00036       LEE, Sara    NaN       M        NY      NaN
# 1700   ID-01701       Jane  Doe   -5.0       F  Nwe Yrok  22kg/m2
# 9966   ID-09967       Jane  Doe  250.0     NaN        la  22kg/m2
#
#      Blood_Pressure Heart_Rate Cholesterol_Level Diabetic     Smoker  \
# 9355            NaN        500            normal       no        NaN
# 7670         118/64         97               250        N  EX-smoker
# 35      120 over 80          0            normal      NaN  EX-smoker
# 1700       120 - 80        500               NaN        y        NaN
# 9966         129/77        500               250        N     Former
#
#              Medications Last_Visit_Date  Follow_Up Diagnosis_Code  \
# 9355  Aspirin; Metformin     Sep 06 2021         30            NaN
# 7670  Aspirin; Metformin      2020-08-11        NaN            NaN
# 35     aspirin,metformin        20210525         14            A00
# 1700   aspirin,metformin      2025-02-10  two weeks        unknown
# 9966                 NaN     Jun 21 2022        NaN            NaN
#
#                        Notes Has_Disease
# 9355  Patient feeling fine 🙂           0
# 7670  BP high, needs recheck     unknown
# 35                       NaN     unknown
# 1700  BP high, needs recheck     unknown
# 9966  BP high, needs recheck           1

# %%
df.dtypes
# Out:
# Patient_ID           object
# Name                 object
# Age                  object
# Gender               object
# City                 object
# BMI                  object
# Blood_Pressure       object
# Heart_Rate           object
# Cholesterol_Level    object
# Diabetic             object
# Smoker               object
# Medications          object
# Last_Visit_Date      object
# Follow_Up            object
# Diagnosis_Code       object
# Notes                object
# Has_Disease          object
# dtype: object

# %%
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

# %%
df.dtypes
# Out:
# Patient_ID            object
# Name                  object
# Age                  float64
# Gender                object
# City                  object
# BMI                   object
# Blood_Pressure        object
# Heart_Rate            object
# Cholesterol_Level     object
# Diabetic              object
# Smoker                object
# Medications           object
# Last_Visit_Date       object
# Follow_Up             object
# Diagnosis_Code        object
# Notes                 object
# Has_Disease           object
# dtype: object
